# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID      City Country  Max Temp Current Description    Lat     Lng  \
# 0        0    Castro      BR     67.14     overcast clouds -24.79  -50.01
# 1        1     Vaini      TO     77.00    scattered clouds -21.20 -175.20
# 2        3   Mataura      NZ     46.99     overcast clouds -46.19  168.86
# 3        4  Belmonte      BR     75.20    scattered clouds -15.86  -38.88
# 4        5  Bengkulu      ID     77.79          few clouds  -3.80  102.27
#
#                     Hotel Name
# 0               CHACARA BAILLY
# 1          Keleti Beach Resort
# 2                Ellie's Villa
# 3  Pousada Monte Carmelo O Pão
# 4         Grage Hotel Bengkulu

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_destination_pick = vacation_df.loc[(vacation_df['Max Temp'] >= 84.4)&(vacation_df['Max Temp'] <= 88.41)]
vacation_destination_pick
# Out:
#      City_ID               City Country  Max Temp   Current Description  \
# 14        18              Pasni      PK     85.03       overcast clouds
# 42        56          Nishihara      JP     86.00         broken clouds
# 73        93              Kapaa      US     87.80             clear sky
# 85       106           Cam Ranh      VN     86.00            few clouds
# 93       115       Port Hedland      AU     87.80       overcast clouds
# 96       121           Nanakuli      US     87.80             clear sky
# 123      151      Makakilo City      US     87.80             clear sky
# 129      158            Kavieng      PG     84.76            light rain
# 140      171              Basco      PH     84.67      scattered clouds
# 141      172  Presidente Medici      BR     84.97             clear sky
# 147      179          Katherine      AU     87.80      scattered clouds
# 149      182          Ewa Beach      US     87.80             clear sky
# 159      194             Turbat      PK     85.17            few clouds
# 180      221           Ishigaki      JP     86.00      scattered clouds
# 196      243           Lorengau      PG     85.01  heavy intensity rain
# 200      249             Barmer      IN     85.30      scattered clouds
# 211      267          Abu Dhabi      AE     87.80             clear sky
# 249      313       San Patricio      MX     86.00         broken clouds
# 287      357         Morant Bay      JM     86.00            few clouds
# 311      385        Keti Bandar      PK     84.76            light rain
# 320      394            Kahului      US     87.80      scattered clouds
# 334      411               Sola      VU     86.00         broken clouds
# 352      433           Umm Lajj      SA     87.78             clear sky
# 372      456             Vanimo      PG     86.81            light rain
# 380      465           Bucerias      MX     87.01       overcast clouds
# 438      540         Texistepec      MX     86.00      scattered clouds
# 439      541                Hit      IQ     86.54             clear sky
# 448      551             Laguna      US     88.00                  haze
# 495      605             Ixtapa      MX     87.01       overcast clouds
# 500      610       Todos Santos      MX     84.99         broken clouds
# 508      619       Muzaffargarh      PK     86.00                 smoke
# 512      624          Alyangula      AU     86.00      scattered clouds
# 524      640      San Cristobal      VE     86.00         broken clouds
# 533      650        Placerville      US     84.99             clear sky
# 561      683             Tam Ky      VN     86.00            few clouds
#
#        Lat     Lng                                         Hotel Name
# 14   25.26   63.47                                     3G hotel pasni
# 42   26.18  127.76                                  Minshuku Agaihama
# 73   22.08 -159.32             Sheraton Kauai Resort at Coconut Beach
# 85   11.92  109.16                                OYO 598 Peony Hotel
# 93  -20.32  118.57                                The Esplanade Hotel
# 96   21.39 -158.15                                       Camp Palehua
# 123  21.35 -158.09                     Marriott's Ko Olina Beach Club
# 129  -2.57  150.80                                Nusa Island Retreat
# 140  20.45  121.97                                  Nathaniel's Lodge
# 141 -11.18  -61.90                              Oliveira Palace Hotel
# 147 -14.47  132.27                                    Pine Tree Motel
# 149  21.32 -158.01                  Hampton Inn & Suites Oahu/Kapolei
# 159  26.00   63.04                                  Mubashar Quarters
# 180  24.34  124.16                      Hotel Peace Land Ishigakijima
# 196  -2.02  147.27                         Lorengau Harbourside Hotel
# 200  25.75   71.38                       OYO 71911 Hotel Amber Palace
# 211  24.47   54.37                                       Beach Rotana
# 249  19.22 -104.70                                  Hotel Cabo Blanco
# 287  17.88  -76.41                      Whispering Bamboo Cove Resort
# 311  24.14   67.45                             Haji laloo memon house
# 320  20.89 -156.47                                 Maui Seaside Hotel
# 334 -13.88  167.55                                 Leumerus Bungalows
# 352  25.02   37.27                         Moon light Furnished Units
# 372  -2.67  141.30                              Vahmoneh Lodge Vanimo
# 380  20.75 -105.33  Villa del Palmar Flamingos Beach Resort & Spa ...
# 438  17.88  -94.78                         AMPLIACIÓN MIGUEL ALEMÁN 2
# 439  33.64   42.83                                    Aboody Alhachem
# 448  38.42 -121.42  Holiday Inn Express & Suites Elk Grove Central...
# 495  20.70 -105.20                      Container Inn Puerto Vallarta
# 500  23.45 -110.22                      Hotel California Todos Santos
# 508  30.08   71.19                                       Aghosh Hotel
# 512 -13.85  136.42                               Groote Eylandt Lodge
# 524   7.77  -72.22                                           Pirineos
# 533  38.73 -120.80                          Historic Cary House Hotel
# 561  15.57  108.48                    Tam Ky Hotels - Tram Oanh Hotel

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'San Patricio']
vacation_end = vacation_df.loc[vacation_df['City'] == 'San Patricio']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Bucerias']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Texistepec'] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Ixtapa']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (vacation_start.to_numpy()[0][5], vacation_start.to_numpy()[0][6])
end = (vacation_end.to_numpy()[0][5], vacation_end.to_numpy()[0][6])
stop1 = (vacation_stop1.to_numpy()[0][5], vacation_stop1.to_numpy()[0][6])
stop2 = (vacation_stop2.to_numpy()[0][5], vacation_stop2.to_numpy()[0][6])
stop3 =(vacation_stop3.to_numpy()[0][5], vacation_stop3.to_numpy()[0][6])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
vacation_directions = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3], travel_mode='DRIVING')
fig.add_layer(vacation_directions)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID          City Country  Max Temp Current Description    Lat     Lng  \
# 0      313  San Patricio      MX     86.00       broken clouds  19.22 -104.70
# 1      465      Bucerias      MX     87.01     overcast clouds  20.75 -105.33
# 2      540    Texistepec      MX     86.00    scattered clouds  17.88  -94.78
# 3      605        Ixtapa      MX     87.01     overcast clouds  20.70 -105.20
#
#                                           Hotel Name
# 0                                  Hotel Cabo Blanco
# 1  Villa del Palmar Flamingos Beach Resort & Spa ...
# 2                         AMPLIACIÓN MIGUEL ALEMÁN 2
# 3                      Container Inn Puerto Vallarta

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
